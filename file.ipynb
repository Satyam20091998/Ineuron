# %% [markdown]
# Q1. How do you load a CSV file into a Pandas DataFrame?

# %%
import pandas as pd
df = pd.read_csv('employees.csv')
print(df)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %% [markdown]
# Q2. How do you check the data type of a column in a Pandas DataFrame?

# %%
print(df['EMPLOYEE_ID'].dtype)
# Out:
# int64

# %% [markdown]
# Q3. How do you select rows from a Pandas DataFrame based on a condition?

# %%
new_df = df[df['SALARY'] > 10000]
print(new_df)
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 3           201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 7           205    Shelley    Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 9           100     Steven       King     SKING  515.123.4567  17-JUN-03
# 10          101      Neena    Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# 11          102        Lex    De Haan   LDEHAAN  515.123.4569  13-JAN-01
# 17          108      Nancy  Greenberg  NGREENBE  515.124.4569  17-AUG-02
# 23          114        Den   Raphaely  DRAPHEAL  515.127.4561  07-DEC-02
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 3    MK_MAN   13000             -         100             20
# 7    AC_MGR   12008             -         101            110
# 9   AD_PRES   24000             -          -              90
# 10    AD_VP   17000             -         100             90
# 11    AD_VP   17000             -         100             90
# ...

# %% [markdown]
# Q4. How do you rename columns in a Pandas DataFrame?

# %%
df = df.rename(columns={'SALARY': 'new_SALARY'})
print(df.columns)
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'new_SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %% [markdown]
# Q5. How do you drop columns in a Pandas DataFrame?

# %%
df = df.drop(['new_SALARY'], axis=1)
print(df.columns)
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'COMMISSION_PCT', 'MANAGER_ID', 'DEPARTMENT_ID'],
#       dtype='object')

# %% [markdown]
# Q6. How do you find the unique values in a column of a Pandas DataFrame?

# %%
unique_values = df['DEPARTMENT_ID'].unique()
print(unique_values)
# Out:
# [ 50  10  20  40  70 110  90  60 100  30]

# %% [markdown]
# Q7. How do you find the number of missing values in each column of a Pandas DataFrame?

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# EMPLOYEE_ID       0
# FIRST_NAME        0
# LAST_NAME         0
# EMAIL             0
# PHONE_NUMBER      0
# HIRE_DATE         0
# JOB_ID            0
# COMMISSION_PCT    0
# MANAGER_ID        0
# DEPARTMENT_ID     0
# dtype: int64

# %% [markdown]
# Q8. How do you fill missing values in a Pandas DataFrame with a specific value?

# %%
df = df.fillna(value=0)

# %% [markdown]
# Q9. How do you concatenate two Pandas DataFrames?

# %%
df1=pd.read_csv('employees.csv')
df2=pd.read_csv('departments.csv')
new_df = pd.concat([df1, df2], axis=0)
print(new_df)
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0         198.0     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1         199.0    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2         200.0   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3         201.0    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4         202.0        Pat        Fay      PFAY  603.123.6666  17-AUG-05
# ..          ...        ...        ...       ...           ...        ...
# 22          NaN        NaN        NaN       NaN           NaN        NaN
# 23          NaN        NaN        NaN       NaN           NaN        NaN
# 24          NaN        NaN        NaN       NaN           NaN        NaN
# 25          NaN        NaN        NaN       NaN           NaN        NaN
# 26          NaN        NaN        NaN       NaN           NaN        NaN
#
#       JOB_ID   SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID  \
# ...

# %% [markdown]
# Q10. How do you merge two Pandas DataFrames on a specific column?

# %%
new_df = pd.merge(df1, df2, on='DEPARTMENT_ID')
print(new_df)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           120      Matthew        Weiss    MWEISS  650.123.1234  18-JUL-04
# 3           121         Adam        Fripp    AFRIPP  650.123.2234  10-APR-05
# 4           122        Payam     Kaufling  PKAUFLIN  650.123.3234  01-MAY-03
# 5           123       Shanta      Vollman  SVOLLMAN  650.123.4234  10-OCT-05
# 6           124        Kevin      Mourgos  KMOURGOS  650.123.5234  16-NOV-07
# 7           125        Julia        Nayer    JNAYER  650.124.1214  16-JUL-05
# 8           126        Irene  Mikkilineni  IMIKKILI  650.124.1224  28-SEP-06
# 9           127        James       Landry   JLANDRY  650.124.1334  14-JAN-07
# 10          128       Steven       Markle   SMARKLE  650.124.1434  08-MAR-08
# ...

# %% [markdown]
# Q11. How do you group data in a Pandas DataFrame by a specific column and apply an aggregation function?

# %%
df4=df.groupby('EMPLOYEE_ID').sum()
print(df4)
# Out:
#              DEPARTMENT_ID
# EMPLOYEE_ID
# 100                     90
# 101                     90
# 102                     90
# 103                     60
# 104                     60
# 105                     60
# 106                     60
# 107                     60
# 108                    100
# 109                    100
# 110                    100
# 111                    100
# 112                    100
# 113                    100
# 114                     30
# 115                     30
# 116                     30
# 117                     30
# 118                     30
# 119                     30
# 120                     50
# 121                     50
# 122                     50
# 123                     50
# 124                     50
# 125                     50
# 126                     50
# 127                     50
# 128                     50
# 129                     50
# 130                     50
# 131                     50
# 132                     50
# ...

# %% [markdown]
# Q12. How do you pivot a Pandas DataFrame?

# %%
df.pivot(index='EMPLOYEE_ID', columns='FIRST_NAME', values='DEPARTMENT_ID').mean()
print(df)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %% [markdown]
# Q13. How do you change the data type of a column in a Pandas DataFrame?

# %%
df['EMPLOYEE_ID'] = df['EMPLOYEE_ID'].astype(int)

# %% [markdown]
# Q14. How do you sort a Pandas DataFrame by a specific column?

# %%
df.sort_values('DEPARTMENT_ID', ascending=True)
print(df)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %% [markdown]
# Q15. How do you create a copy of a Pandas DataFrame?

# %%
df_copy = df.copy()

# %% [markdown]
# Q16. How do you filter rows of a Pandas DataFrame by multiple conditions?

# %%
df[(df['FIRST_NAME'] =='Donald') & (df['JOB_ID'] == 'SH_CLERK')]
print(df)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %% [markdown]
# Q17. How do you calculate the mean of a column in a Pandas DataFrame?

# %%
df['DEPARTMENT_ID'].mean()
# Out:
# 57.6

# %% [markdown]
# Q18. How do you calculate the standard deviation of a column in a Pandas DataFrame?

# %%
df['DEPARTMENT_ID'].std()
# Out:
# 25.116869686669613

# %% [markdown]
# Q19. How do you calculate the correlation between two columns in a Pandas DataFrame?

# %%
df['EMPLOYEE_ID'].corr(df['DEPARTMENT_ID'])
# Out:
# -0.19445633601402473

# %% [markdown]
# Q20. How do you select specific columns in a DataFrame using their labels?

# %%
df.loc[:, ['EMAIL', 'PHONE_NUMBER']]
print(df)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %% [markdown]
# Q21. How do you select specific rows in a DataFrame using their indexes?

# %%
df.loc[[20, 30], :]
print(df)
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %% [markdown]
# Q22. How do you sort a DataFrame by a specific column?

# %%
df.sort_values('SALARY')
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 41          132           TJ        Olson   TJOLSON  650.124.8234  10-APR-07
# 45          136        Hazel   Philtanker  HPHILTAN  650.127.1634  06-FEB-08
# 37          128       Steven       Markle   SMARKLE  650.124.1434  08-MAR-08
# 44          135           Ki          Gee      KGEE  650.127.1734  12-DEC-07
# 36          127        James       Landry   JLANDRY  650.124.1334  14-JAN-07
# 49          140       Joshua        Patel    JPATEL  650.121.1834  06-APR-06
# 40          131        James       Marlow   JAMRLOW  650.124.7234  16-FEB-05
# 28          119        Karen   Colmenares  KCOLMENA  515.127.4566  10-AUG-07
# 27          118          Guy       Himuro   GHIMURO  515.127.4565  15-NOV-06
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# ...

# %% [markdown]
# Q23. How do you create a new column in a DataFrame based on the values of another column?

# %%
df['B'] = 2 * df['EMPLOYEE_ID']
df
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1           199      Douglas        Grant    DGRANT  650.507.9844  13-JAN-08
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4           202          Pat          Fay      PFAY  603.123.6666  17-AUG-05
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777  07-JUN-02
# 6           204      Hermann         Baer     HBAER  515.123.8888  07-JUN-02
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080  07-JUN-02
# 8           206      William        Gietz    WGIETZ  515.123.8181  07-JUN-02
# 9           100       Steven         King     SKING  515.123.4567  17-JUN-03
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568  21-SEP-05
# ...

# %% [markdown]
# Q24. How do you remove duplicates from a DataFrame?

# %%
df.drop_duplicates(subset='EMPLOYEE_ID', inplace=True)

# %% [markdown]
# Q25. What is the difference between .loc and .iloc in Pandas?
#
# Ans-.loc and .iloc are both indexers in Pandas used to select specific rows and columns in a DataFrame. The main difference is that .loc uses the labels of rows and columns, while .iloc uses integer-based positions.
